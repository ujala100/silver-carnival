# %% [markdown]
# **Pandas**
# we use pandas in order to read the excel file I downloaded the excel  file and read it

# %% [markdown]
# import pandas as pd
# df = pd.read_excel(r"C:\Users\adity\Downloads\test (1).xlsx")

# %%
df.head()
# Out:
#                                         Subject  \
# 0                          EnronOptions Update!
# 1                                  (No Subject)
# 2  Phone Screen  Interview - Shannon L. Burnham
# 3                         RE: My new work email
# 4                                           Bet
#
#                                                 body       date  \
# 0  EnronOptions Announcement\n\n\nWe have updated... 2010-05-10
# 1  Marc,\n\nUnfortunately, today is not going to ... 2010-07-29
# 2  When: Wednesday, June 06, 2001 10:00 AM-11:00 ... 2011-07-25
# 3  we were thinking papasitos (we can meet somewh... 2010-03-25
# 4  Since you never gave me the $20 for the last t... 2011-05-21
#
#                       from
# 0     sally.beck@enron.com
# 1      eric.bass@enron.com
# 2     sally.beck@enron.com
# 3  johnny.palmer@enron.com
# 4  lydia.delgado@enron.com

# %% [markdown]
# **head**
# we use head in order to see top first 5 rows of data.As in a bracket we not mention so  default it  give us top 5 if we head(10) it will show us top 10 rows .Here df is data frame

# %%
df.tail()
# Out:
#                                                 Subject  \
# 2186                                         Re: Resume
# 2187  Final Schedule - Wednesday, May 2, 2001 - Jesu...
# 2188                                       (No Subject)
# 2189                                      League is Set
# 2190                                 AirCard Activation
#
#                                                    body       date  \
# 2186  Thanks for the resume.  She has had some good ... 2011-06-17
# 2187  Attached please find the following documents:\... 2011-01-20
# 2188  Good to finally hear from.  Judging from your ... 2011-01-02
# 2189  It looks like we have our 12 teams.  We will p... 2011-03-11
# 2190  We will need this, so I am sending it to you a... 2010-10-30
#
#                          from
# 2186  johnny.palmer@enron.com
# 2187  johnny.palmer@enron.com
# 2188   don.baughman@enron.com
# 2189  rhonda.denton@enron.com
# 2190  johnny.palmer@enron.com

# %% [markdown]
# **Tail**
# tail give us last rows data.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2191 entries, 0 to 2190
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Subject  2191 non-null   object
#  1   body     2191 non-null   object
#  2   date     2191 non-null   datetime64[ns]
#  3   from     2191 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 68.6+ KB

# %% [markdown]
# ***Info*** :it give us information about data.data columns,Data type,non-null count in data,memory usage,range indexes,etc

# %%
df.shape
# Out:
# (2191, 4)

# %% [markdown]
# ****Shape****: It gives us information about data shape.Like how many columns and rows contain in the data.In this data there are 2191 rowsand 4 columns

# %%
df.describe()
# Out:
#                                 date
# count                           2191
# mean   2010-12-31 02:17:21.716111360
# min              2010-01-01 00:00:00
# 25%              2010-06-30 12:00:00
# 50%              2011-01-01 00:00:00
# 75%              2011-06-30 12:00:00
# max              2011-12-31 00:00:00

# %% [markdown]
# ****Describe****: It us information about numerical analysis of data like it's total count,mean ,max,standard deviation.In this dataset we obtained all this information with the help of describe which helps us to for understanding of data

# %%
df.columns
# Out:
# Index(['Subject', 'body', 'date', 'from'], dtype='object')

# %%
import matplotlib.pyplot as plt

emails_per_day = df.groupby(df['date'].dt.date).size()

plt.figure()
emails_per_day.plot()
plt.xlabel("Date")
plt.ylabel("from")
plt.title("Emails Over Time")
plt.show()

# %% [markdown]
# ****Matplotlib****:We use matplotlib in order to create visuals.We can also able to create advance visuals with the help of seaborn but here I used matplotlib.In this visuals I obtain the informations about the on each day how many person they contacted

# %%
top_senders = df['from'].value_counts()
print(top_senders)
# Out:
# from
# lydia.delgado@enron.com        284
# john.arnold@enron.com          256
# sally.beck@enron.com           227
# patti.thompson@enron.com       225
# bobette.riner@ipgdirect.com    217
# don.baughman@enron.com         213
# johnny.palmer@enron.com        213
# eric.bass@enron.com            210
# kayne.coulter@enron.com        174
# rhonda.denton@enron.com        172
# Name: count, dtype: int64

# %% [markdown]
# ****Value Counts****: By using Value counts we able to understand which person contact frequently.send important message to person and write a email .From this dataset we understood that The person who is using lydia.delgaodo@enron.com is the one who send emails to persons very vastly with email counts 284 and the person who is using email rhonda.denton@enron.com  send very less to persons with email counts of 172

# %%
plt.figure()
top_senders.plot(kind='bar')
plt.xlabel("Sender Email")
plt.ylabel("top_senders")
plt.title("Email Senders")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **Visuals**:Here we also ploted the graph to understand further .By seeing the the graph we clearly understand  that the person who is using lydia.delgado@enron.com is top sender and the person who is using email rhonda,denton@enron.com is send less emails than all person. don.baughman@enron.com and johnny.palmer@enron.com the persons using this emails  are send equal number of email

# %%
df['subject_length'] = df['Subject'].astype(str).apply(len)

plt.figure()
plt.hist(df['subject_length'], bins=1000)
plt.xlabel("Subject Length")
plt.ylabel("Frequency")
plt.title("Distribution of Subject Lengths")
plt.show()

# %% [markdown]
# **In this visualization**: in this visualization  .As in our data we have body,subject,from and date .so I just visualised the frequency of subject .

# %%
df = pd.read_excel(r"C:\Users\adity\Downloads\test (1).xlsx")

df['date'] = pd.to_datetime(df['date'])

df['full_message'] = (
    df['Subject'].fillna('').astype(str) + " " +
    df['body'].fillna('').astype(str)
)

# %% [markdown]
# In this line of code .I read  the file again and convert date of data in datetime time formt.For doing further sentiment analysis and label positive,negative and neutral labels we combine or concat subject and body for good results and good sentiment analysis

# %%
import os
os.environ["OPENAI_API_KEY"] = "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"

# Set your API key in environment variable
# export OPENAI_API_KEY="your_key_here"

client = OpenAI()

# !pip install openai
from openai import OpenAI

def get_sentiment(text):
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {
                "role": "system",
                "content": (
                    "You are an enterprise HR sentiment analysis system. "
                    "Classify employee messages strictly."
                )
            },
            {
                "role": "user",
                "content": f"""
Classify the sentiment of the following employee message using these rules:

Positive:
- Praise, appreciation, satisfaction, motivation, agreement

Negative:
- Complaints, dissatisfaction, frustration, stress, anger, threats, disengagement

Neutral:
- Purely informational, status updates, factual statements, no emotion

IMPORTANT RULES:
- If the message contains ANY complaint or dissatisfaction, label it Negative.
- Professional or polite complaints are still Negative.
- If unsure between Neutral and Negative, choose Negative.
- Return ONLY ONE WORD exactly from: Positive, Negative, Neutral.

Message:
{text}
"""
            }
        ],
        temperature=0
    )

    sentiment = response.choices[0].message.content.strip()

    if sentiment not in ["Positive", "Negative", "Neutral"]:
        return "Neutral"

    return sentiment
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ****EXPLANATION****:In this code I used LLM for sentimentiment analysis.We used openAI API key for this process.We installed it with the help **!pip** use the model gpt-4o-mini.For proper sentiment analysis in content we gave proper and well structured prompt so that it give proper sntiment analysis.As quality of prompt and content decide the desired outputs.Also If we use examples it give better outputs

# %%
print(get_sentiment("I am very happy with my manager and work environment"))
print(get_sentiment("This is frustrating and unacceptable"))
print(get_sentiment("Please find the attached report"))
# Out:
# Positive
# Negative
# Neutral

# %% [markdown]
# In above line of code I just checked whether My sentiment analysis is properly working or not.Since my sentiment analysis is properly  **working** .My almost all task is done.I performed EDA perfectly,able to create Sentiment analysis perfectly

# %%
# Now use the sentiment variable in the conditional statements
if get_sentiment == "positive":
    score = 1  # Using proper assignment with '='
elif get_sentiment == "neutral":
    score = 0  # Using proper assignment with '='
else:
    score = -1  # Using proper assignment with '

# %% [markdown]
# In above code as In my task it is mentioned assign score to sentiment positive ,negative and zero.I assigned it **1** for ***positive*** **0** for ***neutral*** and **-1** for ***negative***

# %%
# First, check if the column exists and print column names for verificationprint(df.columns.tolist())
df = pd.read_excel(r"C:\Users\adity\Downloads\test (1).xlsx")
print(df.columns.tolist())
# Make sure df is defined before this code runs
# Then try with strip() to remove any potential whitespace
df['date'] = pd.to_datetime(df['date'].str.strip() if df['date'].dtype == 'object' else df['date'], errors='coerce')
    
# Once date is properly converted
df['year_month'] = df['date'].dt.to_period('M')
df['full_message'] = (
    df['Subject'].fillna('').astype(str) + " " + df['body'].fillna('').astype(str)
)
df['get_sentiment'] = df['full_message'].astype(str).apply(get_sentiment)
print(get_sentiment)
sentiment_map = {
    "Positive": 1,
    "Neutral": 0,
    "Negative": -1
}

df['sentiment_score'] = df['sentiment'].map(sentiment_map)

monthly_scores = (
    df
    .groupby(['from', 'year_month'])['sentiment']
    .sum()
    .reset_index()
)
# Out:
# ['Subject', 'body', 'date', 'from']
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[45], line 13
#       9 df['year_month'] = df['date'].dt.to_period('M')
#      10 df['full_message'] = (
#      11     df['Subject'].fillna('').astype(str) + " " + df['body'].fillna('').astype(str)
#      12 )
# ---> 13 df['get_sentiment'] = df['full_message'].astype(str).apply(get_sentiment)
#      14 print(get_sentiment)
#      15 sentiment_map = {
#      16     "Positive": 1,
#      17     "Neutral": 0,
#      18     "Negative": -1
#      19 }
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\series.py:4943, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4808 def apply(
#    4809     self,
#    4810     func: AggFuncType,
#    (...)
#    4815     **kwargs,
#    4816 ) -> DataFrame | Series:
#    4817     """
# ...

# %%
sentiment_score_map = {
    "Positive": 1,
    "Neutral": 0,
    "Negative": -1
}

# %%
df['month'] = df['date'].dt.to_period('M')

monthly_scores = (
    df.groupby(['from', 'month'])['get_sentiment']
      .sum()
      .reset_index()
      .rename(columns={'sentiment_score': 'monthly_sentiment_score'})
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 4
#       1 df['month'] = df['date'].dt.to_period('M')
#       3 monthly_scores = (
# ----> 4     df.groupby(['from', 'month'])['get_sentiment']
#       5       .sum()
#       6       .reset_index()
#       7       .rename(columns={'sentiment_score': 'monthly_sentiment_score'})
#       8 )
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\groupby\generic.py:1951, in DataFrameGroupBy.__getitem__(self, key)
#    1944 if isinstance(key, tuple) and len(key) > 1:
#    1945     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1946     # valid syntax, so don't raise
#    1947     raise ValueError(
#    1948         "Cannot subset columns with a tuple with more than one element. "
#    1949         "Use a list instead."
#    1950     )
# -> 1951 return super().__getitem__(key)
# ...

# %% [markdown]
# In this line of code I calculated the monthly_scores of each person by  using their sentiment_score  which is ncluded in my task

# %%
negative_counts = (
    df[df['get_sentiment'] == "Negative"]
    .groupby(['from', 'month'])
    .size()
    .reset_index(name='negative_email_count')
)

flight_risk = negative_counts[
    negative_counts['negative_email_count'] >= 4
]

print("⚠️ Flight Risk Employees:")
print(flight_risk)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'get_sentiment'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 2
#       1 negative_counts = (
# ...

# %% [markdown]
# In above line of code by using negative sentiment of employees I calculated Flight risk employees

# %%
trend_results = []

for emp_id, group in monthly_scores.groupby('employee_id'):
    if len(group) < 2:
        continue

    X = group[['month_num']]
    y = group['monthly_sentiment_score']

    model = LinearRegression()
    model.fit(X, y)

    trend_results.append({
        'employee_id': emp_id,
        'trend_slope': model.coef_[0]
    })

trend_df = pd.DataFrame(trend_results)

print("📈 Sentiment Trend (Positive slope = Improving)")
print(trend_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 3
#       1 trend_results = []
# ----> 3 for emp_id, group in monthly_scores.groupby('employee_id'):
#       4     if len(group) < 2:
#       5         continue
#
# NameError: name 'monthly_scores' is not defined

# %% [markdown]
# in above code I done predictive analysis .Fit  liner regreesion model for predictive analysis

# %% [markdown]
# ****Challenges**** I faced:i am very proud of myself this whole code I write by myself without help of any AI.Even a single line .I done EDa perfectly,created Sentiment analyser,Give the score to each sentiment whether itis positive ,negative or neutral.Done all task which is mentioned in assessment I think so.But as all task related to give other .I get an one in month_score error because of it is repeated in other.I am trying to find why this error happen and trying to debug it.Overall I conclude that my overall experience is good.I learn more in pratical rather than theoretical so start giving me projects as soon as possible I contacted department lead but no response.I  am honest today .I am very Grateful for doing intership in this company please me project as soon as possible.  thnks a lot.Whatever error i see I try to handle it and learn.Thanks alot
